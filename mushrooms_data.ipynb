# %%
import pandas as pd

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
from subprocess import check_output

# %%
mushrooms_data=pd.read_csv("C:\\Users\\nk54532\\Downloads\\mushrooms.csv")
mushrooms_data.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color   ...   stalk-surface-below-ring  \
# 0            c         n          k   ...                          s
# 1            c         b          k   ...                          s
# 2            c         b          n   ...                          s
# 3            c         n          n   ...                          s
# 4            w         b          k   ...                          s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
mushrooms_data.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
mushrooms_data[:]
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# 5        e         x           y         y       t    a               f
# 6        e         b           s         w       t    a               f
# 7        e         b           y         w       t    l               f
# 8        p         x           y         w       t    p               f
# 9        e         b           s         y       t    a               f
# 10       e         x           y         y       t    l               f
# 11       e         x           y         y       t    a               f
# 12       e         b           s         y       t    a               f
# 13       p         x           y         w       t    p               f
# 14       e         x           f         n       f    n               f
# 15       e         s           f         g       f    n               f
# 16       e         f           f         w       f    n               f
# 17       p         x           s         n       t    p               f
# 18       p         x           y         w       t    p               f
# 19       p         x           s         n       t    p               f
# 20       e         b           s         y       t    a               f
# 21       p         x           y         n       t    p               f
# 22       e         b           y         y       t    l               f
# 23       e         b           y         w       t    a               f
# 24       e         b           s         w       t    l               f
# 25       p         f           s         w       t    p               f
# 26       e         x           y         y       t    a               f
# 27       e         x           y         w       t    l               f
# 28       e         f           f         n       f    n               f
# 29       e         x           s         y       t    a               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8094     e         b           s         g       f    n               f
# 8095     p         x           y         c       f    m               f
# 8096     e         k           f         w       f    n               f
# 8097     p         k           y         n       f    s               f
# 8098     p         k           s         e       f    y               f
# 8099     e         k           f         w       f    n               f
# 8100     e         f           s         n       f    n               a
# 8101     p         k           s         e       f    s               f
# 8102     e         x           s         n       f    n               a
# 8103     e         k           s         n       f    n               a
# 8104     e         k           s         n       f    n               a
# 8105     e         k           s         n       f    n               a
# 8106     e         k           s         n       f    n               a
# 8107     e         x           s         n       f    n               a
# 8108     p         k           y         e       f    y               f
# 8109     e         b           s         w       f    n               f
# 8110     e         x           s         n       f    n               a
# 8111     e         k           s         w       f    n               f
# 8112     e         k           s         n       f    n               a
# 8113     p         k           y         e       f    y               f
# 8114     p         f           y         c       f    m               a
# 8115     e         x           s         n       f    n               a
# 8116     p         k           y         n       f    s               f
# 8117     p         k           s         e       f    y               f
# 8118     p         k           y         n       f    f               f
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color   ...   stalk-surface-below-ring  \
# 0               c         n          k   ...                          s
# 1               c         b          k   ...                          s
# 2               c         b          n   ...                          s
# 3               c         n          n   ...                          s
# 4               w         b          k   ...                          s
# 5               c         b          n   ...                          s
# 6               c         b          g   ...                          s
# 7               c         b          n   ...                          s
# 8               c         n          p   ...                          s
# 9               c         b          g   ...                          s
# 10              c         b          g   ...                          s
# 11              c         b          n   ...                          s
# 12              c         b          w   ...                          s
# 13              c         n          k   ...                          s
# 14              w         b          n   ...                          f
# 15              c         n          k   ...                          s
# 16              w         b          k   ...                          s
# 17              c         n          n   ...                          s
# 18              c         n          n   ...                          s
# 19              c         n          k   ...                          s
# 20              c         b          k   ...                          s
# 21              c         n          n   ...                          s
# 22              c         b          k   ...                          s
# 23              c         b          w   ...                          s
# 24              c         b          g   ...                          s
# 25              c         n          n   ...                          s
# 26              c         b          n   ...                          s
# 27              c         b          w   ...                          s
# 28              c         n          k   ...                          s
# 29              w         n          n   ...                          s
# ...           ...       ...        ...   ...                        ...
# 8094            w         b          g   ...                          s
# 8095            c         b          y   ...                          y
# 8096            w         b          w   ...                          s
# 8097            c         n          b   ...                          k
# 8098            c         n          b   ...                          k
# 8099            w         b          w   ...                          k
# 8100            c         b          o   ...                          s
# 8101            c         n          b   ...                          s
# 8102            c         b          y   ...                          s
# 8103            c         b          y   ...                          s
# 8104            c         b          y   ...                          s
# 8105            c         b          y   ...                          s
# 8106            c         b          o   ...                          s
# 8107            c         b          y   ...                          s
# 8108            c         n          b   ...                          s
# 8109            w         b          w   ...                          s
# 8110            c         b          o   ...                          s
# 8111            w         b          p   ...                          s
# 8112            c         b          o   ...                          s
# 8113            c         n          b   ...                          k
# 8114            c         b          y   ...                          y
# 8115            c         b          y   ...                          s
# 8116            c         n          b   ...                          k
# 8117            c         n          b   ...                          s
# 8118            c         n          b   ...                          s
# 8119            c         b          y   ...                          s
# 8120            c         b          y   ...                          s
# 8121            c         b          n   ...                          s
# 8122            c         n          b   ...                          k
# 8123            c         b          y   ...                          s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                         w                      w         p          w
# 1                         w                      w         p          w
# 2                         w                      w         p          w
# 3                         w                      w         p          w
# 4                         w                      w         p          w
# 5                         w                      w         p          w
# 6                         w                      w         p          w
# 7                         w                      w         p          w
# 8                         w                      w         p          w
# 9                         w                      w         p          w
# 10                        w                      w         p          w
# 11                        w                      w         p          w
# 12                        w                      w         p          w
# 13                        w                      w         p          w
# 14                        w                      w         p          w
# 15                        w                      w         p          w
# 16                        w                      w         p          w
# 17                        w                      w         p          w
# 18                        w                      w         p          w
# 19                        w                      w         p          w
# 20                        w                      w         p          w
# 21                        w                      w         p          w
# 22                        w                      w         p          w
# 23                        w                      w         p          w
# 24                        w                      w         p          w
# 25                        w                      w         p          w
# 26                        w                      w         p          w
# 27                        w                      w         p          w
# 28                        w                      w         p          w
# 29                        w                      w         p          w
# ...                     ...                    ...       ...        ...
# 8094                      w                      w         p          w
# 8095                      c                      c         p          w
# 8096                      w                      w         p          w
# 8097                      p                      p         p          w
# 8098                      w                      p         p          w
# 8099                      w                      w         p          w
# 8100                      o                      o         p          n
# 8101                      p                      w         p          w
# 8102                      o                      o         p          n
# 8103                      o                      o         p          n
# 8104                      o                      o         p          o
# 8105                      o                      o         p          n
# 8106                      o                      o         p          o
# 8107                      o                      o         p          o
# 8108                      p                      w         p          w
# 8109                      w                      w         p          w
# 8110                      o                      o         p          o
# 8111                      w                      w         p          w
# 8112                      o                      o         p          n
# 8113                      p                      p         p          w
# 8114                      c                      c         p          w
# 8115                      o                      o         p          o
# 8116                      p                      w         p          w
# 8117                      p                      w         p          w
# 8118                      p                      w         p          w
# 8119                      o                      o         p          o
# 8120                      o                      o         p          n
# 8121                      o                      o         p          o
# 8122                      w                      w         p          w
# 8123                      o                      o         p          o
#
#      ring-number ring-type spore-print-color population habitat
# 0              o         p                 k          s       u
# 1              o         p                 n          n       g
# 2              o         p                 n          n       m
# 3              o         p                 k          s       u
# 4              o         e                 n          a       g
# 5              o         p                 k          n       g
# 6              o         p                 k          n       m
# 7              o         p                 n          s       m
# 8              o         p                 k          v       g
# 9              o         p                 k          s       m
# 10             o         p                 n          n       g
# 11             o         p                 k          s       m
# 12             o         p                 n          s       g
# 13             o         p                 n          v       u
# 14             o         e                 k          a       g
# 15             o         p                 n          y       u
# 16             o         e                 n          a       g
# 17             o         p                 k          s       g
# 18             o         p                 n          s       u
# 19             o         p                 n          s       u
# 20             o         p                 n          s       m
# 21             o         p                 n          v       g
# 22             o         p                 n          s       m
# 23             o         p                 n          n       m
# 24             o         p                 k          s       m
# 25             o         p                 n          v       g
# 26             o         p                 n          n       m
# 27             o         p                 n          n       m
# 28             o         p                 k          y       u
# 29             o         p                 n          v       d
# ...          ...       ...               ...        ...     ...
# 8094           t         p                 w          n       g
# 8095           n         n                 w          c       d
# 8096           t         p                 w          n       g
# 8097           o         e                 w          v       l
# 8098           o         e                 w          v       d
# 8099           t         p                 w          s       g
# 8100           o         p                 b          v       l
# 8101           o         e                 w          v       p
# 8102           o         p                 n          c       l
# 8103           o         p                 o          c       l
# 8104           o         p                 n          v       l
# 8105           o         p                 y          v       l
# 8106           o         p                 n          v       l
# 8107           o         p                 n          c       l
# 8108           o         e                 w          v       l
# 8109           t         p                 w          n       g
# 8110           o         p                 n          v       l
# 8111           t         p                 w          n       g
# 8112           o         p                 b          v       l
# 8113           o         e                 w          v       d
# 8114           n         n                 w          c       d
# 8115           o         p                 o          v       l
# 8116           o         e                 w          v       l
# 8117           o         e                 w          v       d
# 8118           o         e                 w          v       d
# 8119           o         p                 b          c       l
# 8120           o         p                 b          v       l
# 8121           o         p                 b          c       l
# 8122           o         e                 w          v       l
# 8123           o         p                 o          c       l
#
# [8124 rows x 23 columns]

# %%
mushrooms_data['class'].unique
# Out:
# <bound method Series.unique of 0       p
# 1       e
# 2       e
# 3       p
# 4       e
# 5       e
# 6       e
# 7       e
# 8       p
# 9       e
# 10      e
# 11      e
# 12      e
# 13      p
# 14      e
# 15      e
# 16      e
# 17      p
# 18      p
# 19      p
# 20      e
# 21      p
# 22      e
# 23      e
# 24      e
# 25      p
# 26      e
# 27      e
# 28      e
# 29      e
#        ..
# 8094    e
# 8095    p
# 8096    e
# 8097    p
# 8098    p
# 8099    e
# 8100    e
# 8101    p
# 8102    e
# 8103    e
# 8104    e
# 8105    e
# 8106    e
# 8107    e
# 8108    p
# 8109    e
# 8110    e
# 8111    e
# 8112    e
# 8113    p
# 8114    p
# 8115    e
# 8116    p
# 8117    p
# 8118    p
# 8119    e
# 8120    e
# 8121    e
# 8122    p
# 8123    e
# Name: class, Length: 8124, dtype: object>

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
for col in mushrooms_data.columns:
    mushrooms_data[col]=labelencoder.fit_transform(mushrooms_data[col])

# %%
mushrooms_data[:]
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# 5         0          5            3          9        1     0
# 6         0          0            2          8        1     0
# 7         0          0            3          8        1     3
# 8         1          5            3          8        1     6
# 9         0          0            2          9        1     0
# 10        0          5            3          9        1     3
# 11        0          5            3          9        1     0
# 12        0          0            2          9        1     0
# 13        1          5            3          8        1     6
# 14        0          5            0          4        0     5
# 15        0          4            0          3        0     5
# 16        0          2            0          8        0     5
# 17        1          5            2          4        1     6
# 18        1          5            3          8        1     6
# 19        1          5            2          4        1     6
# 20        0          0            2          9        1     0
# 21        1          5            3          4        1     6
# 22        0          0            3          9        1     3
# 23        0          0            3          8        1     0
# 24        0          0            2          8        1     3
# 25        1          2            2          8        1     6
# 26        0          5            3          9        1     0
# 27        0          5            3          8        1     3
# 28        0          2            0          4        0     5
# 29        0          5            2          9        1     0
# ...     ...        ...          ...        ...      ...   ...
# 8094      0          0            2          3        0     5
# 8095      1          5            3          1        0     4
# 8096      0          3            0          8        0     5
# 8097      1          3            3          4        0     7
# 8098      1          3            2          2        0     8
# 8099      0          3            0          8        0     5
# 8100      0          2            2          4        0     5
# 8101      1          3            2          2        0     7
# 8102      0          5            2          4        0     5
# 8103      0          3            2          4        0     5
# 8104      0          3            2          4        0     5
# 8105      0          3            2          4        0     5
# 8106      0          3            2          4        0     5
# 8107      0          5            2          4        0     5
# 8108      1          3            3          2        0     8
# 8109      0          0            2          8        0     5
# 8110      0          5            2          4        0     5
# 8111      0          3            2          8        0     5
# 8112      0          3            2          4        0     5
# 8113      1          3            3          2        0     8
# 8114      1          2            3          1        0     4
# 8115      0          5            2          4        0     5
# 8116      1          3            3          4        0     7
# 8117      1          3            2          2        0     8
# 8118      1          3            3          4        0     2
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color   ...     \
# 0                   1             0          1           4   ...
# 1                   1             0          0           4   ...
# 2                   1             0          0           5   ...
# 3                   1             0          1           5   ...
# 4                   1             1          0           4   ...
# 5                   1             0          0           5   ...
# 6                   1             0          0           2   ...
# 7                   1             0          0           5   ...
# 8                   1             0          1           7   ...
# 9                   1             0          0           2   ...
# 10                  1             0          0           2   ...
# 11                  1             0          0           5   ...
# 12                  1             0          0          10   ...
# 13                  1             0          1           4   ...
# 14                  1             1          0           5   ...
# 15                  1             0          1           4   ...
# 16                  1             1          0           4   ...
# 17                  1             0          1           5   ...
# 18                  1             0          1           5   ...
# 19                  1             0          1           4   ...
# 20                  1             0          0           4   ...
# 21                  1             0          1           5   ...
# 22                  1             0          0           4   ...
# 23                  1             0          0          10   ...
# 24                  1             0          0           2   ...
# 25                  1             0          1           5   ...
# 26                  1             0          0           5   ...
# 27                  1             0          0          10   ...
# 28                  1             0          1           4   ...
# 29                  1             1          1           5   ...
# ...               ...           ...        ...         ...   ...
# 8094                1             1          0           2   ...
# 8095                1             0          0          11   ...
# 8096                1             1          0          10   ...
# 8097                1             0          1           0   ...
# 8098                1             0          1           0   ...
# 8099                1             1          0          10   ...
# 8100                0             0          0           6   ...
# 8101                1             0          1           0   ...
# 8102                0             0          0          11   ...
# 8103                0             0          0          11   ...
# 8104                0             0          0          11   ...
# 8105                0             0          0          11   ...
# 8106                0             0          0           6   ...
# 8107                0             0          0          11   ...
# 8108                1             0          1           0   ...
# 8109                1             1          0          10   ...
# 8110                0             0          0           6   ...
# 8111                1             1          0           7   ...
# 8112                0             0          0           6   ...
# 8113                1             0          1           0   ...
# 8114                0             0          0          11   ...
# 8115                0             0          0          11   ...
# 8116                1             0          1           0   ...
# 8117                1             0          1           0   ...
# 8118                1             0          1           0   ...
# 8119                0             0          0          11   ...
# 8120                0             0          0          11   ...
# 8121                0             0          0           5   ...
# 8122                1             0          1           0   ...
# 8123                0             0          0          11   ...
#
#       stalk-surface-below-ring  stalk-color-above-ring  \
# 0                            2                       7
# 1                            2                       7
# 2                            2                       7
# 3                            2                       7
# 4                            2                       7
# 5                            2                       7
# 6                            2                       7
# 7                            2                       7
# 8                            2                       7
# 9                            2                       7
# 10                           2                       7
# 11                           2                       7
# 12                           2                       7
# 13                           2                       7
# 14                           0                       7
# 15                           2                       7
# 16                           2                       7
# 17                           2                       7
# 18                           2                       7
# 19                           2                       7
# 20                           2                       7
# 21                           2                       7
# 22                           2                       7
# 23                           2                       7
# 24                           2                       7
# 25                           2                       7
# 26                           2                       7
# 27                           2                       7
# 28                           2                       7
# 29                           2                       7
# ...                        ...                     ...
# 8094                         2                       7
# 8095                         3                       1
# 8096                         2                       7
# 8097                         1                       6
# 8098                         1                       7
# 8099                         1                       7
# 8100                         2                       5
# 8101                         2                       6
# 8102                         2                       5
# 8103                         2                       5
# 8104                         2                       5
# 8105                         2                       5
# 8106                         2                       5
# 8107                         2                       5
# 8108                         2                       6
# 8109                         2                       7
# 8110                         2                       5
# 8111                         2                       7
# 8112                         2                       5
# 8113                         1                       6
# 8114                         3                       1
# 8115                         2                       5
# 8116                         1                       6
# 8117                         2                       6
# 8118                         2                       6
# 8119                         2                       5
# 8120                         2                       5
# 8121                         2                       5
# 8122                         1                       7
# 8123                         2                       5
#
#       stalk-color-below-ring  veil-type  veil-color  ring-number  ring-type  \
# 0                          7          0           2            1          4
# 1                          7          0           2            1          4
# 2                          7          0           2            1          4
# 3                          7          0           2            1          4
# 4                          7          0           2            1          0
# 5                          7          0           2            1          4
# 6                          7          0           2            1          4
# 7                          7          0           2            1          4
# 8                          7          0           2            1          4
# 9                          7          0           2            1          4
# 10                         7          0           2            1          4
# 11                         7          0           2            1          4
# 12                         7          0           2            1          4
# 13                         7          0           2            1          4
# 14                         7          0           2            1          0
# 15                         7          0           2            1          4
# 16                         7          0           2            1          0
# 17                         7          0           2            1          4
# 18                         7          0           2            1          4
# 19                         7          0           2            1          4
# 20                         7          0           2            1          4
# 21                         7          0           2            1          4
# 22                         7          0           2            1          4
# 23                         7          0           2            1          4
# 24                         7          0           2            1          4
# 25                         7          0           2            1          4
# 26                         7          0           2            1          4
# 27                         7          0           2            1          4
# 28                         7          0           2            1          4
# 29                         7          0           2            1          4
# ...                      ...        ...         ...          ...        ...
# 8094                       7          0           2            2          4
# 8095                       1          0           2            0          3
# 8096                       7          0           2            2          4
# 8097                       6          0           2            1          0
# 8098                       6          0           2            1          0
# 8099                       7          0           2            2          4
# 8100                       5          0           0            1          4
# 8101                       7          0           2            1          0
# 8102                       5          0           0            1          4
# 8103                       5          0           0            1          4
# 8104                       5          0           1            1          4
# 8105                       5          0           0            1          4
# 8106                       5          0           1            1          4
# 8107                       5          0           1            1          4
# 8108                       7          0           2            1          0
# 8109                       7          0           2            2          4
# 8110                       5          0           1            1          4
# 8111                       7          0           2            2          4
# 8112                       5          0           0            1          4
# 8113                       6          0           2            1          0
# 8114                       1          0           2            0          3
# 8115                       5          0           1            1          4
# 8116                       7          0           2            1          0
# 8117                       7          0           2            1          0
# 8118                       7          0           2            1          0
# 8119                       5          0           1            1          4
# 8120                       5          0           0            1          4
# 8121                       5          0           1            1          4
# 8122                       7          0           2            1          0
# 8123                       5          0           1            1          4
#
#       spore-print-color  population  habitat
# 0                     2           3        5
# 1                     3           2        1
# 2                     3           2        3
# 3                     2           3        5
# 4                     3           0        1
# 5                     2           2        1
# 6                     2           2        3
# 7                     3           3        3
# 8                     2           4        1
# 9                     2           3        3
# 10                    3           2        1
# 11                    2           3        3
# 12                    3           3        1
# 13                    3           4        5
# 14                    2           0        1
# 15                    3           5        5
# 16                    3           0        1
# 17                    2           3        1
# 18                    3           3        5
# 19                    3           3        5
# 20                    3           3        3
# 21                    3           4        1
# 22                    3           3        3
# 23                    3           2        3
# 24                    2           3        3
# 25                    3           4        1
# 26                    3           2        3
# 27                    3           2        3
# 28                    2           5        5
# 29                    3           4        0
# ...                 ...         ...      ...
# 8094                  7           2        1
# 8095                  7           1        0
# 8096                  7           2        1
# 8097                  7           4        2
# 8098                  7           4        0
# 8099                  7           3        1
# 8100                  0           4        2
# 8101                  7           4        4
# 8102                  3           1        2
# 8103                  4           1        2
# 8104                  3           4        2
# 8105                  8           4        2
# 8106                  3           4        2
# 8107                  3           1        2
# 8108                  7           4        2
# 8109                  7           2        1
# 8110                  3           4        2
# 8111                  7           2        1
# 8112                  0           4        2
# 8113                  7           4        0
# 8114                  7           1        0
# 8115                  4           4        2
# 8116                  7           4        2
# 8117                  7           4        0
# 8118                  7           4        0
# 8119                  0           1        2
# 8120                  0           4        2
# 8121                  0           1        2
# 8122                  7           4        2
# 8123                  4           1        2
#
# [8124 rows x 23 columns]

# %%
mushrooms_data['stalk-color-above-ring'].unique()
# Out:
# array([7, 3, 6, 4, 0, 2, 5, 1, 8], dtype=int64)

# %%
print(mushrooms_data.groupby('class').size())
# Out:
# class
# 0    4208
# 1    3916
# dtype: int64

# %%
ax=sns.boxplot(x='class',y='stalk-surface-above-ring',
               data=mushrooms_data)
ax=sns.stripplot(x='class',y='stalk-surface-above-ring',
                     data=mushrooms_data,jitter=True,
                     edgecolor="gray")
sns.plt.title("Class wrt stalkcolor above ring",fontsize=12)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-62a54d998619> in <module>()
#       4                      data=mushrooms_data,jitter=True,
#       5                      edgecolor="gray")
# ----> 6 sns.plt.title("Class wrt stalkcolor above ring",fontsize=12)
#       7 plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'plt'

# %%
X=mushrooms_data.iloc[:,1:23]
y=mushrooms_data.iloc[:,0]
X.head()
y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: class, dtype: int64

# %%
X.describe()
# Out:
#          cap-shape  cap-surface    cap-color      bruises         odor  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      3.348104     1.827671     4.504677     0.415559     4.144756
# std       1.604329     1.229873     2.545821     0.492848     2.103729
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     0.000000     3.000000     0.000000     2.000000
# 50%       3.000000     2.000000     4.000000     0.000000     5.000000
# 75%       5.000000     3.000000     8.000000     1.000000     5.000000
# max       5.000000     3.000000     9.000000     1.000000     8.000000
#
#        gill-attachment  gill-spacing    gill-size   gill-color  stalk-shape  \
# count      8124.000000   8124.000000  8124.000000  8124.000000  8124.000000
# mean          0.974151      0.161497     0.309207     4.810684     0.567208
# std           0.158695      0.368011     0.462195     3.540359     0.495493
# min           0.000000      0.000000     0.000000     0.000000     0.000000
# 25%           1.000000      0.000000     0.000000     2.000000     0.000000
# 50%           1.000000      0.000000     0.000000     5.000000     1.000000
# 75%           1.000000      0.000000     1.000000     7.000000     1.000000
# max           1.000000      1.000000     1.000000    11.000000     1.000000
#
#           ...       stalk-surface-below-ring  stalk-color-above-ring  \
# count     ...                    8124.000000             8124.000000
# mean      ...                       1.603644                5.816347
# std       ...                       0.675974                1.901747
# min       ...                       0.000000                0.000000
# 25%       ...                       1.000000                6.000000
# 50%       ...                       2.000000                7.000000
# 75%       ...                       2.000000                7.000000
# max       ...                       3.000000                8.000000
#
#        stalk-color-below-ring  veil-type   veil-color  ring-number  \
# count             8124.000000     8124.0  8124.000000  8124.000000
# mean                 5.794682        0.0     1.965534     1.069424
# std                  1.907291        0.0     0.242669     0.271064
# min                  0.000000        0.0     0.000000     0.000000
# 25%                  6.000000        0.0     2.000000     1.000000
# 50%                  7.000000        0.0     2.000000     1.000000
# 75%                  7.000000        0.0     2.000000     1.000000
# max                  8.000000        0.0     3.000000     2.000000
#
#          ring-type  spore-print-color   population      habitat
# count  8124.000000        8124.000000  8124.000000  8124.000000
# mean      2.291974           3.596750     3.644018     1.508616
# std       1.801672           2.382663     1.252082     1.719975
# min       0.000000           0.000000     0.000000     0.000000
# 25%       0.000000           2.000000     3.000000     0.000000
# 50%       2.000000           3.000000     4.000000     1.000000
# 75%       4.000000           7.000000     4.000000     2.000000
# max       4.000000           8.000000     5.000000     6.000000
#
# [8 rows x 22 columns]

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: class, dtype: int64

# %%
mushrooms_data.corr()
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     1.000000   0.052951     0.178446  -0.031384
# cap-shape                 0.052951   1.000000    -0.050454  -0.048203
# cap-surface               0.178446  -0.050454     1.000000  -0.019402
# cap-color                -0.031384  -0.048203    -0.019402   1.000000
# bruises                  -0.501530  -0.035374     0.070228  -0.000764
# odor                     -0.093552  -0.021935     0.045233  -0.387121
# gill-attachment           0.129200   0.078865    -0.034180   0.041436
# gill-spacing             -0.348387   0.013196    -0.282306   0.144259
# gill-size                 0.540024   0.054050     0.208100  -0.169464
# gill-color               -0.530566  -0.006039    -0.161017   0.084659
# stalk-shape              -0.102019   0.063794    -0.014123  -0.456496
# stalk-root               -0.379361   0.030191    -0.126245   0.321274
# stalk-surface-above-ring -0.334593  -0.030417     0.089090  -0.060837
# stalk-surface-below-ring -0.298801  -0.032591     0.107965  -0.047710
# stalk-color-above-ring   -0.154003  -0.031659     0.066050   0.002364
# stalk-color-below-ring   -0.146730  -0.030390     0.068885   0.008057
# veil-type                      NaN        NaN          NaN        NaN
# veil-color                0.145142   0.072560    -0.016603   0.036130
# ring-number              -0.214366  -0.106534    -0.026147  -0.005822
# ring-type                -0.411771  -0.025457    -0.106407   0.162513
# spore-print-color         0.171961  -0.073416     0.230364  -0.293523
# population                0.298686   0.063413     0.021555  -0.144770
# habitat                   0.217179  -0.042221     0.163887   0.033925
#
#                            bruises      odor  gill-attachment  gill-spacing  \
# class                    -0.501530 -0.093552         0.129200     -0.348387
# cap-shape                -0.035374 -0.021935         0.078865      0.013196
# cap-surface               0.070228  0.045233        -0.034180     -0.282306
# cap-color                -0.000764 -0.387121         0.041436      0.144259
# bruises                   1.000000 -0.061825         0.137359     -0.299473
# odor                     -0.061825  1.000000        -0.059590      0.063936
# gill-attachment           0.137359 -0.059590         1.000000      0.071489
# gill-spacing             -0.299473  0.063936         0.071489      1.000000
# gill-size                -0.369596  0.310495         0.108984     -0.108333
# gill-color                0.527120 -0.129213        -0.128567      0.100193
# stalk-shape               0.099364  0.459766         0.186485      0.080895
# stalk-root                0.244188 -0.205215         0.144063      0.350548
# stalk-surface-above-ring  0.460824  0.118617        -0.088916     -0.212359
# stalk-surface-below-ring  0.458983  0.061820        -0.116177     -0.213775
# stalk-color-above-ring    0.083538  0.174532         0.099299      0.274574
# stalk-color-below-ring    0.092874  0.169407         0.097160      0.253505
# veil-type                      NaN       NaN              NaN           NaN
# veil-color                0.119770 -0.057747         0.897518      0.073363
# ring-number               0.056788  0.111905         0.093236      0.243014
# ring-type                 0.692973 -0.281387        -0.146689     -0.195897
# spore-print-color        -0.285008  0.469055        -0.029524      0.047323
# population                0.088137 -0.043623         0.165575     -0.529253
# habitat                  -0.075095 -0.026610        -0.030304     -0.154680
#
#                           gill-size  gill-color    ...     \
# class                      0.540024   -0.530566    ...
# cap-shape                  0.054050   -0.006039    ...
# cap-surface                0.208100   -0.161017    ...
# cap-color                 -0.169464    0.084659    ...
# bruises                   -0.369596    0.527120    ...
# odor                       0.310495   -0.129213    ...
# gill-attachment            0.108984   -0.128567    ...
# gill-spacing              -0.108333    0.100193    ...
# gill-size                  1.000000   -0.516736    ...
# gill-color                -0.516736    1.000000    ...
# stalk-shape                0.214576   -0.175699    ...
# stalk-root                -0.344345    0.315080    ...
# stalk-surface-above-ring   0.056310    0.224287    ...
# stalk-surface-below-ring   0.010894    0.257224    ...
# stalk-color-above-ring     0.296548   -0.058299    ...
# stalk-color-below-ring     0.278708   -0.074781    ...
# veil-type                       NaN         NaN    ...
# veil-color                 0.103809   -0.097583    ...
# ring-number               -0.171362    0.096054    ...
# ring-type                 -0.460872    0.629398    ...
# spore-print-color          0.622991   -0.416135    ...
# population                 0.147682   -0.034090    ...
# habitat                    0.161418   -0.202972    ...
#
#                           stalk-surface-below-ring  stalk-color-above-ring  \
# class                                    -0.298801               -0.154003
# cap-shape                                -0.032591               -0.031659
# cap-surface                               0.107965                0.066050
# cap-color                                -0.047710                0.002364
# bruises                                   0.458983                0.083538
# odor                                      0.061820                0.174532
# gill-attachment                          -0.116177                0.099299
# gill-spacing                             -0.213775                0.274574
# gill-size                                 0.010894                0.296548
# gill-color                                0.257224               -0.058299
# stalk-shape                              -0.034399                0.223439
# stalk-root                                0.087454                0.157140
# stalk-surface-above-ring                  0.437164                0.132708
# stalk-surface-below-ring                  1.000000                0.106933
# stalk-color-above-ring                    0.106933                1.000000
# stalk-color-below-ring                    0.110656                0.491510
# veil-type                                      NaN                     NaN
# veil-color                               -0.077284                0.067377
# ring-number                               0.040006                0.084917
# ring-type                                 0.394644               -0.048878
# spore-print-color                         0.130974                0.271533
# population                                0.046797               -0.240261
# habitat                                  -0.039628                0.042561
#
#                           stalk-color-below-ring  veil-type  veil-color  \
# class                                  -0.146730        NaN    0.145142
# cap-shape                              -0.030390        NaN    0.072560
# cap-surface                             0.068885        NaN   -0.016603
# cap-color                               0.008057        NaN    0.036130
# bruises                                 0.092874        NaN    0.119770
# odor                                    0.169407        NaN   -0.057747
# gill-attachment                         0.097160        NaN    0.897518
# gill-spacing                            0.253505        NaN    0.073363
# gill-size                               0.278708        NaN    0.103809
# gill-color                             -0.074781        NaN   -0.097583
# stalk-shape                             0.235794        NaN    0.162604
# stalk-root                              0.159805        NaN    0.156213
# stalk-surface-above-ring                0.142835        NaN   -0.090591
# stalk-surface-below-ring                0.110656        NaN   -0.077284
# stalk-color-above-ring                  0.491510        NaN    0.067377
# stalk-color-below-ring                  1.000000        NaN    0.065567
# veil-type                                    NaN        NaN         NaN
# veil-color                              0.065567        NaN    1.000000
# ring-number                             0.087580        NaN    0.036380
# ring-type                              -0.034284        NaN   -0.143673
# spore-print-color                       0.254518        NaN   -0.003600
# population                             -0.242792        NaN    0.124924
# habitat                                 0.041594        NaN   -0.040581
#
#                           ring-number  ring-type  spore-print-color  \
# class                       -0.214366  -0.411771           0.171961
# cap-shape                   -0.106534  -0.025457          -0.073416
# cap-surface                 -0.026147  -0.106407           0.230364
# cap-color                   -0.005822   0.162513          -0.293523
# bruises                      0.056788   0.692973          -0.285008
# odor                         0.111905  -0.281387           0.469055
# gill-attachment              0.093236  -0.146689          -0.029524
# gill-spacing                 0.243014  -0.195897           0.047323
# gill-size                   -0.171362  -0.460872           0.622991
# gill-color                   0.096054   0.629398          -0.416135
# stalk-shape                 -0.293221  -0.291444           0.258831
# stalk-root                  -0.247357   0.210155          -0.536996
# stalk-surface-above-ring     0.107904   0.390091           0.100764
# stalk-surface-below-ring     0.040006   0.394644           0.130974
# stalk-color-above-ring       0.084917  -0.048878           0.271533
# stalk-color-below-ring       0.087580  -0.034284           0.254518
# veil-type                         NaN        NaN                NaN
# veil-color                   0.036380  -0.143673          -0.003600
# ring-number                  1.000000   0.058312           0.338417
# ring-type                    0.058312   1.000000          -0.487048
# spore-print-color            0.338417  -0.487048           1.000000
# population                  -0.242020   0.211763          -0.126859
# habitat                      0.235835  -0.212080           0.185954
#
#                           population   habitat
# class                       0.298686  0.217179
# cap-shape                   0.063413 -0.042221
# cap-surface                 0.021555  0.163887
# cap-color                  -0.144770  0.033925
# bruises                     0.088137 -0.075095
# odor                       -0.043623 -0.026610
# gill-attachment             0.165575 -0.030304
# gill-spacing               -0.529253 -0.154680
# gill-size                   0.147682  0.161418
# gill-color                 -0.034090 -0.202972
# stalk-shape                 0.087383 -0.269216
# stalk-root                 -0.306747 -0.007668
# stalk-surface-above-ring    0.079604 -0.058076
# stalk-surface-below-ring    0.046797 -0.039628
# stalk-color-above-ring     -0.240261  0.042561
# stalk-color-below-ring     -0.242792  0.041594
# veil-type                        NaN       NaN
# veil-color                  0.124924 -0.040581
# ring-number                -0.242020  0.235835
# ring-type                   0.211763 -0.212080
# spore-print-color          -0.126859  0.185954
# population                  1.000000 -0.174529
# habitat                    -0.174529  1.000000
#
# [23 rows x 23 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler =StandardScaler()
X=scaler.fit_transform(X)
X
# Out:
# array([[ 1.02971224,  0.14012794, -0.19824983, ..., -0.67019486,
#         -0.5143892 ,  2.03002809],
#        [ 1.02971224,  0.14012794,  1.76587407, ..., -0.2504706 ,
#         -1.31310821, -0.29572966],
#        [-2.08704716,  0.14012794,  1.37304929, ..., -0.2504706 ,
#         -1.31310821,  0.86714922],
#        ...,
#        [-0.8403434 ,  0.14012794, -0.19824983, ..., -1.50964337,
#         -2.11182722,  0.28570978],
#        [-0.21699152,  0.95327039, -0.19824983, ...,  1.42842641,
#          0.28432981,  0.28570978],
#        [ 1.02971224,  0.14012794, -0.19824983, ...,  0.16925365,
#         -2.11182722,  0.28570978]])

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA()
pca.fit_transform(X)
# Out:
# array([[ -5.74321902e-01,  -9.75781349e-01,  -1.22176154e+00, ...,
#          -2.08581362e-01,   8.13996758e-03,  -2.98716006e-17],
#        [ -2.28210230e+00,   2.79066333e-01,  -1.20049669e+00, ...,
#           1.52238789e-01,  -1.96446132e-01,   8.17047124e-17],
#        [ -1.85803562e+00,  -2.70972362e-01,  -1.37237069e+00, ...,
#           2.57581784e-01,  -3.62577199e-01,   3.62451933e-17],
#        ...,
#        [ -1.62151632e+00,  -7.57536709e-01,   2.73357994e+00, ...,
#          -1.42532241e+00,   6.36990122e-01,   1.31607921e-18],
#        [  3.67060561e+00,  -1.03277450e+00,   1.68459501e-01, ...,
#           9.41440123e-02,  -6.43462238e-02,  -7.47641463e-20],
#        [ -1.57520272e+00,  -1.22858140e+00,   2.44722789e+00, ...,
#          -8.04626064e-01,   5.90315263e-01,   1.39554149e-19]])

# %%
covariance=pca.get_covariance()

# %%
explained_variance=pca.explained_variance_

# %%
explained_variance
# Out:
# array([  3.87410924e+00,   2.60339434e+00,   2.40073834e+00,
#          2.16674719e+00,   1.70303181e+00,   1.39495575e+00,
#          9.78803667e-01,   9.51936841e-01,   7.70036405e-01,
#          7.11748353e-01,   5.77556532e-01,   5.42484855e-01,
#          5.09631267e-01,   4.77214086e-01,   3.84467203e-01,
#          3.11228233e-01,   2.18649656e-01,   1.59514884e-01,
#          1.31521687e-01,   7.31993474e-02,   6.16155691e-02,
#          2.78307611e-33])

# %%
with plt.style.context('dark_background'):
    plt.figure(figsize=(6,4))
    plt.bar(range(22),explained_variance,alpha=0.5,align='center',
           label='indivial explained variance')
    plt.ylabel('explained varience ratio')
    plt.xlabel('principal component')
    plt.legend(loc='best')
    plt.tight_layout()
    plt.show()

# %%
N=mushrooms_data.values
pca = PCA(n_components=2)
x = pca.fit_transform(N)
plt.figure(figsize = (5,5))
plt.scatter(x[:,0],x[:,1])
plt.show()

# %%
from sklearn.cluster import KMeans
kmeans=KMeans(n_clusters=2,random_state=5)
X_clustered=kmeans.fit_predict(N)
LABEL_COLOR_MAP={0:'g',1:'y'
                }
label_color=[LABEL_COLOR_MAP[1] for l in X_clustered]
plt.figure(figsize=(5,5))
plt.scatter(x[:,0],x[:,1],c=label_color)
plt.show()

# %%
pca_modified=PCA(n_components=17)
pca_modified.fit_transform(X)
# Out:
# array([[-0.5743219 , -0.97578135, -1.22176154, ..., -0.51996599,
#         -0.78254366,  1.12025933],
#        [-2.2821023 ,  0.27906633, -1.20049669, ..., -0.11307822,
#         -0.73093408, -0.01817413],
#        [-1.85803562, -0.27097236, -1.37237069, ...,  0.01652548,
#         -0.6561675 ,  0.10791396],
#        ...,
#        [-1.62151632, -0.75753671,  2.73357994, ..., -0.51961303,
#         -0.70768708,  0.22578534],
#        [ 3.67060561, -1.0327745 ,  0.1684595 , ..., -0.08688401,
#         -0.11464249, -0.14801392],
#        [-1.57520272, -1.2285814 ,  2.44722789, ...,  0.91606764,
#         -0.77988482, -0.30141893]])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=4)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn import metrics

model_LR=LogisticRegression()

# %%
model_LR.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_prob=model_LR.predict_proba(X_test)[:,1]
y_pred=np.where(y_prob>0.5,1,0)
model_LR.score(X_test,y_pred)
# Out:
# 1.0

# %%
confusion_matrix=metrics.confusion_matrix(y_test,y_pred)
confusion_matrix
# Out:
# array([[814,  31],
#        [ 37, 743]], dtype=int64)

# %%
aus_roc=metrics.roc_auc_score(y_test,y_pred)
aus_roc
# Out:
# 0.95793885601577911

# %%
from sklearn.metrics import roc_curve,auc
false_positive_rate, true_positive_rate,threshold=roc_curve(y_test,y_prob)
roc_auc=auc(false_positive_rate,true_positive_rate)
roc_auc
# Out:
# 0.9902988924290701

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.title('Receiver Operation Characteristic')
plt.plot(false_positive_rate,true_positive_rate,color='red',label='AUC=%0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],linestyle='--')
plt.axis('tight')
plt.ylabel('True positive Rate')
plt.xlabel('False positive Rate')
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn import metrics
LR_model=LogisticRegression()
tuned_parameteres={'C':[0.001, 0.01, 0.1, 1, 10, 100, 1000],'penalty':['l1','l2']
                  }

# %%
mushrooms_data.corr()
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     1.000000   0.052951     0.178446  -0.031384
# cap-shape                 0.052951   1.000000    -0.050454  -0.048203
# cap-surface               0.178446  -0.050454     1.000000  -0.019402
# cap-color                -0.031384  -0.048203    -0.019402   1.000000
# bruises                  -0.501530  -0.035374     0.070228  -0.000764
# odor                     -0.093552  -0.021935     0.045233  -0.387121
# gill-attachment           0.129200   0.078865    -0.034180   0.041436
# gill-spacing             -0.348387   0.013196    -0.282306   0.144259
# gill-size                 0.540024   0.054050     0.208100  -0.169464
# gill-color               -0.530566  -0.006039    -0.161017   0.084659
# stalk-shape              -0.102019   0.063794    -0.014123  -0.456496
# stalk-root               -0.379361   0.030191    -0.126245   0.321274
# stalk-surface-above-ring -0.334593  -0.030417     0.089090  -0.060837
# stalk-surface-below-ring -0.298801  -0.032591     0.107965  -0.047710
# stalk-color-above-ring   -0.154003  -0.031659     0.066050   0.002364
# stalk-color-below-ring   -0.146730  -0.030390     0.068885   0.008057
# veil-type                      NaN        NaN          NaN        NaN
# veil-color                0.145142   0.072560    -0.016603   0.036130
# ring-number              -0.214366  -0.106534    -0.026147  -0.005822
# ring-type                -0.411771  -0.025457    -0.106407   0.162513
# spore-print-color         0.171961  -0.073416     0.230364  -0.293523
# population                0.298686   0.063413     0.021555  -0.144770
# habitat                   0.217179  -0.042221     0.163887   0.033925
#
#                            bruises      odor  gill-attachment  gill-spacing  \
# class                    -0.501530 -0.093552         0.129200     -0.348387
# cap-shape                -0.035374 -0.021935         0.078865      0.013196
# cap-surface               0.070228  0.045233        -0.034180     -0.282306
# cap-color                -0.000764 -0.387121         0.041436      0.144259
# bruises                   1.000000 -0.061825         0.137359     -0.299473
# odor                     -0.061825  1.000000        -0.059590      0.063936
# gill-attachment           0.137359 -0.059590         1.000000      0.071489
# gill-spacing             -0.299473  0.063936         0.071489      1.000000
# gill-size                -0.369596  0.310495         0.108984     -0.108333
# gill-color                0.527120 -0.129213        -0.128567      0.100193
# stalk-shape               0.099364  0.459766         0.186485      0.080895
# stalk-root                0.244188 -0.205215         0.144063      0.350548
# stalk-surface-above-ring  0.460824  0.118617        -0.088916     -0.212359
# stalk-surface-below-ring  0.458983  0.061820        -0.116177     -0.213775
# stalk-color-above-ring    0.083538  0.174532         0.099299      0.274574
# stalk-color-below-ring    0.092874  0.169407         0.097160      0.253505
# veil-type                      NaN       NaN              NaN           NaN
# veil-color                0.119770 -0.057747         0.897518      0.073363
# ring-number               0.056788  0.111905         0.093236      0.243014
# ring-type                 0.692973 -0.281387        -0.146689     -0.195897
# spore-print-color        -0.285008  0.469055        -0.029524      0.047323
# population                0.088137 -0.043623         0.165575     -0.529253
# habitat                  -0.075095 -0.026610        -0.030304     -0.154680
#
#                           gill-size  gill-color    ...     \
# class                      0.540024   -0.530566    ...
# cap-shape                  0.054050   -0.006039    ...
# cap-surface                0.208100   -0.161017    ...
# cap-color                 -0.169464    0.084659    ...
# bruises                   -0.369596    0.527120    ...
# odor                       0.310495   -0.129213    ...
# gill-attachment            0.108984   -0.128567    ...
# gill-spacing              -0.108333    0.100193    ...
# gill-size                  1.000000   -0.516736    ...
# gill-color                -0.516736    1.000000    ...
# stalk-shape                0.214576   -0.175699    ...
# stalk-root                -0.344345    0.315080    ...
# stalk-surface-above-ring   0.056310    0.224287    ...
# stalk-surface-below-ring   0.010894    0.257224    ...
# stalk-color-above-ring     0.296548   -0.058299    ...
# stalk-color-below-ring     0.278708   -0.074781    ...
# veil-type                       NaN         NaN    ...
# veil-color                 0.103809   -0.097583    ...
# ring-number               -0.171362    0.096054    ...
# ring-type                 -0.460872    0.629398    ...
# spore-print-color          0.622991   -0.416135    ...
# population                 0.147682   -0.034090    ...
# habitat                    0.161418   -0.202972    ...
#
#                           stalk-surface-below-ring  stalk-color-above-ring  \
# class                                    -0.298801               -0.154003
# cap-shape                                -0.032591               -0.031659
# cap-surface                               0.107965                0.066050
# cap-color                                -0.047710                0.002364
# bruises                                   0.458983                0.083538
# odor                                      0.061820                0.174532
# gill-attachment                          -0.116177                0.099299
# gill-spacing                             -0.213775                0.274574
# gill-size                                 0.010894                0.296548
# gill-color                                0.257224               -0.058299
# stalk-shape                              -0.034399                0.223439
# stalk-root                                0.087454                0.157140
# stalk-surface-above-ring                  0.437164                0.132708
# stalk-surface-below-ring                  1.000000                0.106933
# stalk-color-above-ring                    0.106933                1.000000
# stalk-color-below-ring                    0.110656                0.491510
# veil-type                                      NaN                     NaN
# veil-color                               -0.077284                0.067377
# ring-number                               0.040006                0.084917
# ring-type                                 0.394644               -0.048878
# spore-print-color                         0.130974                0.271533
# population                                0.046797               -0.240261
# habitat                                  -0.039628                0.042561
#
#                           stalk-color-below-ring  veil-type  veil-color  \
# class                                  -0.146730        NaN    0.145142
# cap-shape                              -0.030390        NaN    0.072560
# cap-surface                             0.068885        NaN   -0.016603
# cap-color                               0.008057        NaN    0.036130
# bruises                                 0.092874        NaN    0.119770
# odor                                    0.169407        NaN   -0.057747
# gill-attachment                         0.097160        NaN    0.897518
# gill-spacing                            0.253505        NaN    0.073363
# gill-size                               0.278708        NaN    0.103809
# gill-color                             -0.074781        NaN   -0.097583
# stalk-shape                             0.235794        NaN    0.162604
# stalk-root                              0.159805        NaN    0.156213
# stalk-surface-above-ring                0.142835        NaN   -0.090591
# stalk-surface-below-ring                0.110656        NaN   -0.077284
# stalk-color-above-ring                  0.491510        NaN    0.067377
# stalk-color-below-ring                  1.000000        NaN    0.065567
# veil-type                                    NaN        NaN         NaN
# veil-color                              0.065567        NaN    1.000000
# ring-number                             0.087580        NaN    0.036380
# ring-type                              -0.034284        NaN   -0.143673
# spore-print-color                       0.254518        NaN   -0.003600
# population                             -0.242792        NaN    0.124924
# habitat                                 0.041594        NaN   -0.040581
#
#                           ring-number  ring-type  spore-print-color  \
# class                       -0.214366  -0.411771           0.171961
# cap-shape                   -0.106534  -0.025457          -0.073416
# cap-surface                 -0.026147  -0.106407           0.230364
# cap-color                   -0.005822   0.162513          -0.293523
# bruises                      0.056788   0.692973          -0.285008
# odor                         0.111905  -0.281387           0.469055
# gill-attachment              0.093236  -0.146689          -0.029524
# gill-spacing                 0.243014  -0.195897           0.047323
# gill-size                   -0.171362  -0.460872           0.622991
# gill-color                   0.096054   0.629398          -0.416135
# stalk-shape                 -0.293221  -0.291444           0.258831
# stalk-root                  -0.247357   0.210155          -0.536996
# stalk-surface-above-ring     0.107904   0.390091           0.100764
# stalk-surface-below-ring     0.040006   0.394644           0.130974
# stalk-color-above-ring       0.084917  -0.048878           0.271533
# stalk-color-below-ring       0.087580  -0.034284           0.254518
# veil-type                         NaN        NaN                NaN
# veil-color                   0.036380  -0.143673          -0.003600
# ring-number                  1.000000   0.058312           0.338417
# ring-type                    0.058312   1.000000          -0.487048
# spore-print-color            0.338417  -0.487048           1.000000
# population                  -0.242020   0.211763          -0.126859
# habitat                      0.235835  -0.212080           0.185954
#
#                           population   habitat
# class                       0.298686  0.217179
# cap-shape                   0.063413 -0.042221
# cap-surface                 0.021555  0.163887
# cap-color                  -0.144770  0.033925
# bruises                     0.088137 -0.075095
# odor                       -0.043623 -0.026610
# gill-attachment             0.165575 -0.030304
# gill-spacing               -0.529253 -0.154680
# gill-size                   0.147682  0.161418
# gill-color                 -0.034090 -0.202972
# stalk-shape                 0.087383 -0.269216
# stalk-root                 -0.306747 -0.007668
# stalk-surface-above-ring    0.079604 -0.058076
# stalk-surface-below-ring    0.046797 -0.039628
# stalk-color-above-ring     -0.240261  0.042561
# stalk-color-below-ring     -0.242792  0.041594
# veil-type                        NaN       NaN
# veil-color                  0.124924 -0.040581
# ring-number                -0.242020  0.235835
# ring-type                   0.211763 -0.212080
# spore-print-color          -0.126859  0.185954
# population                  1.000000 -0.174529
# habitat                    -0.174529  1.000000
#
# [23 rows x 23 columns]

# %%
from sklearn.model_selection import GridSearchCV
LR=GridSearchCV(LR_model,tuned_parameteres,cv=10)

# %%
LR.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=10, error_score='raise',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000], 'penalty': ['l1', 'l2']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
print(LR.best_params_)
# Out:
# {'C': 100, 'penalty': 'l1'}

# %%
y_prob = LR.predict_proba(X_test)[:,1] 
y_pred = np.where(y_prob > 0.5, 1, 0) 
LR.score(X_test, y_pred)
# Out:
# 1.0

# %%
confusion_matrix=metrics.confusion_matrix(y_test,y_pred)
confusion_matrix
# Out:
# array([[824,  21],
#        [ 23, 757]], dtype=int64)

# %%
auc_roc=metrics.classification_report(y_test,y_pred)
aus_roc
# Out:
# 0.95793885601577911

# %%
auc_roc=metrics.roc_auc_score(y_test,y_pred)
aus_roc
# Out:
# 0.95793885601577911

# %%
from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# 0.9916325292064937

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
LR_ridge= LogisticRegression(penalty='l2')
LR_ridge.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_prob = LR_ridge.predict_proba(X_test)[:,1]  
y_pred = np.where(y_prob > 0.5, 1, 0) 
LR_ridge.score(X_test, y_pred)
# Out:
# 1.0

# %%
confusion_matrix=metrics.confusion_matrix(y_test,y_pred)
confusion_matrix
# Out:
# array([[814,  31],
#        [ 37, 743]], dtype=int64)

# %%
auc_roc=metrics.classification_report(y_test,y_pred)
auc_roc
# Out:
# '             precision    recall  f1-score   support\n\n          0       0.96      0.96      0.96       845\n          1       0.96      0.95      0.96       780\n\navg / total       0.96      0.96      0.96      1625\n'

# %%
auc_roc=metrics.roc_auc_score(y_test,y_pred)
auc_roc
# Out:
# 0.95793885601577911

# %%
from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# 0.9902988924290701

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
model_naive = GaussianNB()
model_naive.fit(X_train, y_train)
# Out:
# GaussianNB(priors=None)

# %%
y_prob = model_naive.predict_proba(X_test)[:,1] 
y_pred = np.where(y_prob > 0.5, 1, 0) 
model_naive.score(X_test, y_pred)
# Out:
# 1.0

# %%
print("Number of mislabeled points from %d points : %d"
      % (X_test.shape[0],(y_test!= y_pred).sum()))
# Out:
# Number of mislabeled points from 1625 points : 111

# %%
scores = cross_val_score(model_naive, X, y, cv=10, scoring='accuracy')
print(scores)
# Out:
# [ 0.59778598  0.78843788  0.97908979  0.9803198   0.84870849  0.81303813
#   0.81034483  0.81650246  0.85326757  0.97533909]

# %%
scores.mean()
# Out:
# 0.84628340228874954

# %%
confusion_matrix=metrics.confusion_matrix(y_test,y_pred)
confusion_matrix
# Out:
# array([[786,  59],
#        [ 52, 728]], dtype=int64)

# %%
auc_roc=metrics.classification_report(y_test,y_pred)
auc_roc
# Out:
# '             precision    recall  f1-score   support\n\n          0       0.94      0.93      0.93       845\n          1       0.93      0.93      0.93       780\n\navg / total       0.93      0.93      0.93      1625\n'

# %%
auc_roc=metrics.roc_auc_score(y_test,y_pred)
auc_roc
# Out:
# 0.9317554240631164

# %%
from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# 0.9592201486876043

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
from sklearn.svm import SVC
svm_model= SVC()

# %%
tuned_parameters = {
 'C': [1, 10, 100,500, 1000], 'kernel': ['linear','rbf'],
 'C': [1, 10, 100,500, 1000], 'gamma': [1,0.1,0.01,0.001, 0.0001], 'kernel': ['rbf'],
 #'degree': [2,3,4,5,6] , 'C':[1,10,100,500,1000] , 'kernel':['poly']
    }

# %%
from sklearn.grid_search import RandomizedSearchCV

model_svm = RandomizedSearchCV(svm_model, tuned_parameters,cv=10,scoring='accuracy',n_iter=20)
# Out:
# C:\Users\nk54532\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Users\nk54532\Anaconda3\lib\site-packages\sklearn\grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
model_svm.fit(X_train, y_train)
print(model_svm.best_score_)
# Out:
# 1.0

# %%
print(model_svm.grid_scores_)
# Out:
# [mean: 1.00000, std: 0.00000, params: {'kernel': 'rbf', 'gamma': 1, 'C': 100}, mean: 1.00000, std: 0.00000, params: {'kernel': 'rbf', 'gamma': 0.1, 'C': 100}, mean: 0.96046, std: 0.00611, params: {'kernel': 'rbf', 'gamma': 0.0001, 'C': 500}, mean: 1.00000, std: 0.00000, params: {'kernel': 'rbf', 'gamma': 0.1, 'C': 500}, mean: 0.94738, std: 0.00972, params: {'kernel': 'rbf', 'gamma': 0.0001, 'C': 100}, mean: 1.00000, std: 0.00000, params: {'kernel': 'rbf', 'gamma': 0.001, 'C': 1000}, mean: 0.97615, std: 0.00607, params: {'kernel': 'rbf', 'gamma': 0.0001, 'C': 1000}, mean: 1.00000, std: 0.00000, params: {'kernel': 'rbf', 'gamma': 0.01, 'C': 1000}, mean: 1.00000, std: 0.00000, params: {'kernel': 'rbf', 'gamma': 0.01, 'C': 500}, mean: 0.94784, std: 0.00840, params: {'kernel': 'rbf', 'gamma': 0.001, 'C': 1}, mean: 1.00000, std: 0.00000, params: {'kernel': 'rbf', 'gamma': 0.01, 'C': 100}, mean: 0.99031, std: 0.00372, params: {'kernel': 'rbf', 'gamma': 0.001, 'C': 100}, mean: 1.00000, std: 0.00000, params: {'kernel': 'rbf', 'gamma': 0.1, 'C': 1}, mean: 1.00000, std: 0.00000, params: {'kernel': 'rbf', 'gamma': 1, 'C': 500}, mean: 0.88798, std: 0.01206, params: {'kernel': 'rbf', 'gamma': 0.0001, 'C': 1}, mean: 1.00000, std: 0.00000, params: {'kernel': 'rbf', 'gamma': 1, 'C': 1000}, mean: 1.00000, std: 0.00000, params: {'kernel': 'rbf', 'gamma': 1, 'C': 10}, mean: 1.00000, std: 0.00000, params: {'kernel': 'rbf', 'gamma': 0.1, 'C': 1000}, mean: 0.98738, std: 0.00329, params: {'kernel': 'rbf', 'gamma': 0.01, 'C': 1}, mean: 1.00000, std: 0.00000, params: {'kernel': 'rbf', 'gamma': 0.1, 'C': 10}]

# %%
print(model_svm.best_params_)
# Out:
# {'kernel': 'rbf', 'gamma': 1, 'C': 100}

# %%
y_pred= model_svm.predict(X_test)
print(metrics.accuracy_score(y_pred,y_test))
# Out:
# 1.0

# %%
confusion_matrix=metrics.confusion_matrix(y_test,y_pred)
confusion_matrix
# Out:
# array([[845,   0],
#        [  0, 780]], dtype=int64)

# %%
auc_roc=metrics.classification_report(y_test,y_pred)
auc_roc
# Out:
# '             precision    recall  f1-score   support\n\n          0       1.00      1.00      1.00       845\n          1       1.00      1.00      1.00       780\n\navg / total       1.00      1.00      1.00      1625\n'

# %%
auc_roc=metrics.roc_auc_score(y_test,y_pred)
auc_roc
# Out:
# 1.0

# %%
from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

model_RR=RandomForestClassifier()

# %%
model_RR.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
y_prob = model_RR.predict_proba(X_test)[:,1] 
y_pred = np.where(y_prob > 0.5, 1, 0) 
model_RR.score(X_test, y_pred)
# Out:
# 1.0

# %%
confusion_matrix=metrics.confusion_matrix(y_test,y_pred)
confusion_matrix
# Out:
# array([[845,   0],
#        [  0, 780]], dtype=int64)

# %%
auc_roc=metrics.classification_report(y_test,y_pred)
auc_roc
# Out:
# '             precision    recall  f1-score   support\n\n          0       1.00      1.00      1.00       845\n          1       1.00      1.00      1.00       780\n\navg / total       1.00      1.00      1.00      1625\n'

# %%
auc_roc=metrics.roc_auc_score(y_test,y_pred)
auc_roc
# Out:
# 1.0

# %%
from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(false_positive_rate, true_positive_rate)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

model_RR=RandomForestClassifier()

tuned_parameters = {'min_samples_leaf': range(10,100,10), 'n_estimators' : range(10,100,10),
                    'max_features':['auto','sqrt','log2']
                    }

# %%
from sklearn.grid_search import RandomizedSearchCV

RR_model= RandomizedSearchCV(model_RR, tuned_parameters,cv=10,scoring='accuracy',n_iter=20,n_jobs= -1)

# %%
RR_model.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=10, error_score='raise',
#           estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#           fit_params={}, iid=True, n_iter=20, n_jobs=-1,
#           param_distributions={'min_samples_leaf': range(10, 100, 10), 'n_estimators': range(10, 100, 10), 'max_features': ['auto', 'sqrt', 'log2']},
#           pre_dispatch='2*n_jobs', random_state=None, refit=True,
#           scoring='accuracy', verbose=0)

# %%
print(RR_model.grid_scores_)
# Out:
# [mean: 0.98354, std: 0.00717, params: {'n_estimators': 30, 'min_samples_leaf': 60, 'max_features': 'auto'}, mean: 0.98554, std: 0.00548, params: {'n_estimators': 60, 'min_samples_leaf': 60, 'max_features': 'auto'}, mean: 0.98600, std: 0.00449, params: {'n_estimators': 40, 'min_samples_leaf': 60, 'max_features': 'sqrt'}, mean: 0.98707, std: 0.00522, params: {'n_estimators': 40, 'min_samples_leaf': 50, 'max_features': 'log2'}, mean: 0.98415, std: 0.00651, params: {'n_estimators': 50, 'min_samples_leaf': 60, 'max_features': 'log2'}, mean: 0.99708, std: 0.00327, params: {'n_estimators': 60, 'min_samples_leaf': 30, 'max_features': 'log2'}, mean: 0.99954, std: 0.00099, params: {'n_estimators': 70, 'min_samples_leaf': 10, 'max_features': 'auto'}, mean: 0.99000, std: 0.00512, params: {'n_estimators': 50, 'min_samples_leaf': 40, 'max_features': 'log2'}, mean: 0.98600, std: 0.00465, params: {'n_estimators': 40, 'min_samples_leaf': 50, 'max_features': 'auto'}, mean: 0.99154, std: 0.00463, params: {'n_estimators': 80, 'min_samples_leaf': 40, 'max_features': 'log2'}, mean: 0.97892, std: 0.00498, params: {'n_estimators': 90, 'min_samples_leaf': 90, 'max_features': 'sqrt'}, mean: 0.99831, std: 0.00161, params: {'n_estimators': 80, 'min_samples_leaf': 20, 'max_features': 'log2'}, mean: 0.98046, std: 0.00345, params: {'n_estimators': 50, 'min_samples_leaf': 90, 'max_features': 'log2'}, mean: 0.99923, std: 0.00103, params: {'n_estimators': 10, 'min_samples_leaf': 10, 'max_features': 'log2'}, mean: 0.99908, std: 0.00157, params: {'n_estimators': 20, 'min_samples_leaf': 10, 'max_features': 'auto'}, mean: 0.97800, std: 0.00569, params: {'n_estimators': 60, 'min_samples_leaf': 90, 'max_features': 'log2'}, mean: 0.99862, std: 0.00145, params: {'n_estimators': 90, 'min_samples_leaf': 30, 'max_features': 'log2'}, mean: 0.98507, std: 0.00525, params: {'n_estimators': 10, 'min_samples_leaf': 50, 'max_features': 'log2'}, mean: 0.97553, std: 0.01069, params: {'n_estimators': 20, 'min_samples_leaf': 90, 'max_features': 'auto'}, mean: 0.99354, std: 0.00558, params: {'n_estimators': 10, 'min_samples_leaf': 30, 'max_features': 'auto'}]

# %%
print(RR_model.best_score_)
# Out:
# 0.9995383905216187

# %%
print(RR_model.best_params_)
# Out:
# {'n_estimators': 70, 'min_samples_leaf': 10, 'max_features': 'auto'}

# %%
y_prob = RR_model.predict_proba(X_test)[:,1]   
y_pred = np.where(y_prob > 0.5, 1, 0) 
RR_model.score(X_test, y_pred)
# Out:
# 1.0

# %%
confusion_matrix=metrics.confusion_matrix(y_test,y_pred)
confusion_matrix
# Out:
# array([[845,   0],
#        [  0, 780]], dtype=int64)

# %%
auc_roc=metrics.classification_report(y_test,y_pred)
auc_roc
# Out:
# '             precision    recall  f1-score   support\n\n          0       1.00      1.00      1.00       845\n          1       1.00      1.00      1.00       780\n\navg / total       1.00      1.00      1.00      1625\n'

# %%
auc_roc=metrics.roc_auc_score(y_test,y_pred)
auc_roc
# Out:
# 1.0

# %%
from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier

model_tree = DecisionTreeClassifier()

# %%
model_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
y_prob = model_tree.predict_proba(X_test)[:,1]   
y_pred = np.where(y_prob > 0.5, 1, 0)
model_tree.score(X_test, y_pred)
# Out:
# 1.0

# %%
confusion_matrix=metrics.confusion_matrix(y_test,y_pred)
confusion_matrix
# Out:
# array([[845,   0],
#        [  0, 780]], dtype=int64)

# %%
auc_roc=metrics.classification_report(y_test,y_pred)
auc_roc
# Out:
# '             precision    recall  f1-score   support\n\n          0       1.00      1.00      1.00       845\n          1       1.00      1.00      1.00       780\n\navg / total       1.00      1.00      1.00      1625\n'

# %%
auc_roc=metrics.roc_auc_score(y_test,y_pred)
auc_roc
# Out:
# 1.0

# %%
from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(false_positive_rate, true_positive_rate)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier

model_DD = DecisionTreeClassifier()

tuned_parameters= {'criterion': ['gini','entropy'], 'max_features': ["auto","sqrt","log2"],
                   'min_samples_leaf': range(1,100,1) , 'max_depth': range(1,50,1)
                  }

# %%
from sklearn.grid_search import RandomizedSearchCV
DD_model= RandomizedSearchCV(model_DD, tuned_parameters,cv=10,scoring='accuracy',n_iter=20,n_jobs= -1,random_state=5)

# %%
DD_model.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=10, error_score='raise',
#           estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           fit_params={}, iid=True, n_iter=20, n_jobs=-1,
#           param_distributions={'criterion': ['gini', 'entropy'], 'max_features': ['auto', 'sqrt', 'log2'], 'min_samples_leaf': range(1, 100), 'max_depth': range(1, 50)},
#           pre_dispatch='2*n_jobs', random_state=5, refit=True,
#           scoring='accuracy', verbose=0)

# %%
print(DD_model.grid_scores_)
# Out:
# [mean: 0.98000, std: 0.00672, params: {'min_samples_leaf': 45, 'max_features': 'log2', 'max_depth': 10, 'criterion': 'gini'}, mean: 0.98784, std: 0.00709, params: {'min_samples_leaf': 27, 'max_features': 'log2', 'max_depth': 14, 'criterion': 'entropy'}, mean: 0.97215, std: 0.01069, params: {'min_samples_leaf': 70, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'entropy'}, mean: 0.96507, std: 0.00842, params: {'min_samples_leaf': 67, 'max_features': 'sqrt', 'max_depth': 40, 'criterion': 'entropy'}, mean: 0.96030, std: 0.01283, params: {'min_samples_leaf': 77, 'max_features': 'auto', 'max_depth': 11, 'criterion': 'gini'}, mean: 0.99692, std: 0.00207, params: {'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 31, 'criterion': 'entropy'}, mean: 0.94922, std: 0.01670, params: {'min_samples_leaf': 76, 'max_features': 'sqrt', 'max_depth': 19, 'criterion': 'gini'}, mean: 0.96199, std: 0.02266, params: {'min_samples_leaf': 67, 'max_features': 'log2', 'max_depth': 41, 'criterion': 'entropy'}, mean: 0.93430, std: 0.02894, params: {'min_samples_leaf': 43, 'max_features': 'sqrt', 'max_depth': 4, 'criterion': 'gini'}, mean: 0.89506, std: 0.04728, params: {'min_samples_leaf': 48, 'max_features': 'sqrt', 'max_depth': 3, 'criterion': 'gini'}, mean: 0.94922, std: 0.03440, params: {'min_samples_leaf': 66, 'max_features': 'auto', 'max_depth': 6, 'criterion': 'entropy'}, mean: 0.98384, std: 0.00830, params: {'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': 7, 'criterion': 'gini'}, mean: 0.95230, std: 0.01899, params: {'min_samples_leaf': 84, 'max_features': 'auto', 'max_depth': 9, 'criterion': 'gini'}, mean: 0.97800, std: 0.00676, params: {'min_samples_leaf': 49, 'max_features': 'auto', 'max_depth': 16, 'criterion': 'entropy'}, mean: 0.97369, std: 0.00978, params: {'min_samples_leaf': 46, 'max_features': 'auto', 'max_depth': 10, 'criterion': 'gini'}, mean: 0.95722, std: 0.01565, params: {'min_samples_leaf': 80, 'max_features': 'log2', 'max_depth': 19, 'criterion': 'entropy'}, mean: 0.96815, std: 0.01903, params: {'min_samples_leaf': 65, 'max_features': 'log2', 'max_depth': 26, 'criterion': 'gini'}, mean: 0.96492, std: 0.01376, params: {'min_samples_leaf': 68, 'max_features': 'auto', 'max_depth': 49, 'criterion': 'entropy'}, mean: 0.99123, std: 0.00579, params: {'min_samples_leaf': 18, 'max_features': 'log2', 'max_depth': 11, 'criterion': 'gini'}, mean: 0.97461, std: 0.00518, params: {'min_samples_leaf': 37, 'max_features': 'sqrt', 'max_depth': 48, 'criterion': 'entropy'}]

# %%
print(DD_model.best_score_)
# Out:
# 0.9969226034774581

# %%
print(DD_model.best_params_)
# Out:
# {'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 31, 'criterion': 'entropy'}

# %%
y_prob = DD_model.predict_proba(X_test)[:,1]
y_pred = np.where(y_prob > 0.5, 1, 0)
DD_model.score(X_test, y_pred)
# Out:
# 1.0

# %%
confusion_matrix=metrics.confusion_matrix(y_test,y_pred)
confusion_matrix
# Out:
# array([[841,   4],
#        [  0, 780]], dtype=int64)

# %%
auc_roc=metrics.classification_report(y_test,y_pred)
auc_roc
# Out:
# '             precision    recall  f1-score   support\n\n          0       1.00      1.00      1.00       845\n          1       0.99      1.00      1.00       780\n\navg / total       1.00      1.00      1.00      1625\n'

# %%
auc_roc=metrics.roc_auc_score(y_test,y_pred)
auc_roc
# Out:
# 0.99763313609467463

# %%
from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
from sklearn.neural_network import MLPClassifier

# %%
mlp = MLPClassifier()
mlp.fit(X_train,y_train)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)

# %%
y_prob = mlp.predict_proba(X_test)[:,1] 
y_pred = np.where(y_prob > 0.5, 1, 0) 
mlp.score(X_test, y_pred)
# Out:
# 1.0

# %%
confusion_matrix=metrics.confusion_matrix(y_test,y_pred)
confusion_matrix
# Out:
# array([[845,   0],
#        [  0, 780]], dtype=int64)

# %%
auc_roc=metrics.classification_report(y_test,y_pred)
auc_roc
# Out:
# '             precision    recall  f1-score   support\n\n          0       1.00      1.00      1.00       845\n          1       1.00      1.00      1.00       780\n\navg / total       1.00      1.00      1.00      1625\n'

# %%
auc_roc=metrics.roc_auc_score(y_test,y_pred)
auc_roc
# Out:
# 1.0

# %%
from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
